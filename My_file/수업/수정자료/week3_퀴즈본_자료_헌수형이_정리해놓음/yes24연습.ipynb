# %%
import requests
from bs4 import BeautifulSoup

# %%
url = 'http://www.yes24.com/24/category/bestseller'
bestseller = requests.get(url)

# %%
bestseller           # 200 : 응답코드 200 은 서버의 응답이 정상,   404 : url 이 잘못되거나 오류
# Out:
# <Response [200]>

# %%
bestseller.content
# Out:
# b'\r\n\t<!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">\r\n\t<html>\r\n\r\n<head><base href="https://www.yes24.com/24/" />\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\r\n\t<meta http-equiv="Content-Type" content="text/html;charset=euc-kr" />\r\n\t<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />\r\n\t<meta http-equiv="Accept-CH-Lifetime" content="86400" />\r\n\t<meta name="referrer" content="unsafe-url" />\r\n\t<meta name="viewport" content="width=1170" />\r\n\r\n\t<title>\xbf\xb9\xbd\xba24 | \xba\xa3\xbd\xba\xc6\xae\xbc\xbf\xb7\xaf</title>\r\n\r\n\t<meta name="title" content="\xbf\xb9\xbd\xba24" />\r\n\t<meta name="description" content="YOUR EVERY STORY \xb9\xae\xc8\xad \xc4\xdc\xc5\xd9\xc3\xf7 \xc7\xc3\xb7\xa7\xc6\xfb, \xbf\xb9\xbd\xba24" />\r\n\t<meta name="keywords" content="\xc0\xce\xc5\xcd\xb3\xdd \xbc\xad\xc1\xa1, \xbf\xc2\xb6\xf3\xc0\xce \xbc
# ...

# %%
# HTML parser 이용해 soup 객체 생성
soup = BeautifulSoup(bestseller.content, 'html.parser')
soup
# Out:
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.01 Transitional//EN">
#
# <html>
# <head><base href="https://www.yes24.com/24/"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" http-equiv="Accept-CH"/>
# <meta content="86400" http-equiv="Accept-CH-Lifetime"/>
# <meta content="unsafe-url" name="referrer"/>
# <meta content="width=1170" name="viewport"/>
# <title>예스24 | 베스트셀러</title>
# <meta content="예스24" name="title"/>
# <meta content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" name="description"/>
# <meta content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" name="keywords"/>
# <link href="//www.yes24.com/OpensearchDescription.xml" rel="search" title="YES24" type="application/opensearchdescription+xml"/>
# ...

# %%
# 책이름 찾아오기 : 브라우저 이용해서 HTML 태그를 찾습니다
# 방법 1)
soup.find("ol", class_="").find("li", class_="num1").find('p').text
# Out:
# '세이노의 ‘요즘 생각’을 만나다 '

# %%
title = soup.find("ol", class_="").find("li", class_="num2").find_all('p')[0]
title
# Out:
# <p class="copy"><a href="/Product/Goods/119608737">유시민의 유쾌한 과학 읽기</a></p>

# %%
# 방법 2)
##bestList > ol > li.num1 > p.copy > a
soup.select('ol > li > p > a')
# Out:
# [<a href="/Product/Goods/117014613">세이노의 ‘요즘 생각’을 만나다 </a>,
#  <a href="/Product/Goods/117014613">
#  <img alt="세이노의 가르침" src="https://image.yes24.com/goods/117014613/L">
#  </img></a>,
#  <a href="/Product/Goods/117014613">세이노의 가르침</a>,
#  <a href="https://www.yes24.com/Product/Search?domain=ALL&amp;query=%ec%84%b8%ec%9d%b4%eb%85%b8(SayNo)&amp;author=%ec%84%b8%ec%9d%b4%eb%85%b8(SayNo)&amp;auth_no=414840" target="_blank">세이노(SayNo)</a>,
#  <a href="https://www.yes24.com/Product/Search?domain=ALL&amp;query=%eb%8d%b0%ec%9d%b4%ec%9b%90&amp;company=%eb%8d%b0%ec%9d%b4%ec%9b%90">데이원</a>,
#  <a href="/Product/Goods/117014613#Review">249개</a>,
#  <a href="javascript:yes24GU.openPreviewCheck(117014613);"><img alt="미리보기" src="https://image.yes24.com/sysimage/bestseller/b_preview.gif"/></a>,
#  <a href="/Product/Goods/117742467"><img alt="eBook" src="https://image.yes24.com/sysimage/detailN/b_eBook02.gif"/></a>,
# ...

# %%
title_2 = soup.select('ol > li > p > a')
title_2[0].text
# Out:
# '세이노의 ‘요즘 생각’을 만나다 '

# %%
soup.find("ol",class_="").find("li",class_="num1").find('p', class_="aupu").text
# Out:
# '세이노(SayNo) 저 | 데이원'

# %%
soup.find("ol",class_="").find("li",class_="num1").find('p', class_="price").text
# Out:
# '6,480원(10%+5%)'

# %%
soup.find("ol",class_="").find("li",class_="num1").find("strong").text
# Out:
# '6,480원'
